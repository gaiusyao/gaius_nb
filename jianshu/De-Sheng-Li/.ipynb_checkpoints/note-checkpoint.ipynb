# %% [markdown]
# ## 0 准备工作

# %% [markdown]
# ### 0.1 import

# %%
import sqlite3
import pandas as pd

import matplotlib .pyplot as plt
plt.style.use('ggplot')
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

import re
import jieba

from wordcloud import WordCloud
from imageio import imread #读取图片

# %% [markdown]
# ### 0.2 读取数据

# %%
# 读取数据库
sql = '''
    SELECT a.id 
        , title
        , date
        , vol
        , period
        , intro
        , content
        , anno
    FROM mzdxj_info a
        , mzdxj_content b
    WHERE a.id = b.id
'''

df = pd.read_sql(sql, con=sqlite3.connect('mao.db'))

# %%
df.shape
# Out:
# (231, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 8 columns):
# id         231 non-null int64
# title      231 non-null object
# date       231 non-null object
# vol        231 non-null int64
# period     231 non-null object
# intro      231 non-null object
# content    231 non-null object
# anno       231 non-null object
# dtypes: int64(2), object(6)
# memory usage: 14.5+ KB

# %%
df.sample(5)
# Out:
#       id          title        date  vol           period  \
# 115  116       关于建立报告制度  1948-01-07    4      第三次国内革命战争时期
# 200  201     原子弹吓不倒中国人民  1955-01-28    5  社会主义革命和社会主义建设时期
# 128  129  新解放区农村工作的策略问题  1948-05-24    4      第三次国内革命战争时期
# 81    82      必须学会做经济工作  1945-01-10    3           抗日战争时期
# 114  115     目前形势和我们的任务  1947-12-25    4      第三次国内革命战争时期
#
#                                                  intro  \
# 115  这是毛泽东为中共中央起草的对党内的指示。这个指示中所规定的报告制度，是中共中央坚持民主集中制...
# 200                  这是毛泽东同志在芬兰首任驻中国大使孙士教递交国书的时候谈话的要点。
# 128                                      这是毛泽东给邓小平的电报。
# 81                        这是毛泽东在陕甘宁边区劳动英雄和模范工作者大会上的讲话。
# 114  这是毛泽东在中共中央一九四七年十二月二十五日至二十八日在陕北米脂县杨家沟召集的会议上的报告。...
#
#                                                content  \
# 115  为了及时反映情况，使中央有可能在事先或事后帮助各地不犯或少犯错误，争取革命战争更加伟大的胜利...
# 200  中国和芬兰是友好的国家。我们的关系，是建立在和平共处五项原则的基础之上的。中国同芬兰从来没有...
# 128  新解放区农村工作的策略问题有全盘考虑之必要。新解放区必须充分利用抗日时期的经验，在解放后的相...
# 81   各位劳动英雄，各位模范工作者！你们开了会，总结了经验，大家欢迎你们，尊敬你们。你们有三种长处...
# 114  一中国人民的革命战争，现在已经达到了一个转折点。这即是中国人民解放军已经打退了美国走狗蒋介石...
#
#                                                   anno
# 115
# 200
# 128
# 81
# 114  〔1〕关于人民解放军在各个战场陆续转入进攻，打到国民党统治区的情况，见本卷《评西北大捷兼论解...

# %% [markdown]
# ### 0.3 相关函数

# %%
def contentToStr(cond, col='period'):
    '''
        将 DataFrame 中的指定内容转化为字符串
        @param cond: filter condition, str
        @param col: column name, str, default 'period'
        @return text: conversion results, str
    '''
    text = ' '.join(df[df[col] == cond]['content'].tolist())
    return text

# %%
stopwords = [line.strip() for line in open('stopwords.txt', 'r').readlines()] #停用词列表

def cutText(text):
    '''
        中文分词，并去除停用词
        @param text: raw text, str
        @return ouput: split text, str
    '''
    cut_text = jieba.cut(text)
    output = ''
    
    for word in cut_text:
        if word not in stopwords:
            if word != '\t':
                output += word
                output += " "
    return output

# %%
cut = cutText(contentToStr('第一次国内革命战争时期'))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users